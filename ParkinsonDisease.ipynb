# %% [markdown]
# <a href="https://colab.research.google.com/github/Sakshi1007/MLnow_2.0/blob/main/ParkinsonDisease.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# * Name - ASCII subject name and recording number
# * MDVP:Fo(Hz) - Average vocal fundamental frequency
# * MDVP:Fhi(Hz) - Maximum vocal fundamental frequency
# * MDVP:Flo(Hz) - Minimum vocal fundamental frequency
# * MDVP:Jitter(%),MDVP:Jitter(Abs),MDVP:RAP,MDVP:PPQ,Jitter:DDP - Several measures of variation in fundamental frequency
# * MDVP:Shimmer,MDVP:Shimmer(dB),Shimmer:APQ3,Shimmer:APQ5,MDVP:APQ,Shimmer:DDA - Several measures of variation in amplitude
# NHR,HNR - Two measures of ratio of noise to tonal components in the voice
# status - Health status of the subject (one) - Parkinson's, (zero) - healthy
# * RPDE,D2 - Two nonlinear dynamical complexity measures
# * DFA - Signal fractal scaling exponent

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv("https://archive.ics.uci.edu/ml/machine-learning-databases/parkinsons/parkinsons.data")

# %%
data.shape
# Out:
# (195, 24)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 24 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   name              195 non-null    object
#  1   MDVP:Fo(Hz)       195 non-null    float64
#  2   MDVP:Fhi(Hz)      195 non-null    float64
#  3   MDVP:Flo(Hz)      195 non-null    float64
#  4   MDVP:Jitter(%)    195 non-null    float64
#  5   MDVP:Jitter(Abs)  195 non-null    float64
#  6   MDVP:RAP          195 non-null    float64
#  7   MDVP:PPQ          195 non-null    float64
#  8   Jitter:DDP        195 non-null    float64
#  9   MDVP:Shimmer      195 non-null    float64
#  10  MDVP:Shimmer(dB)  195 non-null    float64
#  11  Shimmer:APQ3      195 non-null    float64
#  12  Shimmer:APQ5      195 non-null    float64
#  13  MDVP:APQ          195 non-null    float64
#  14  Shimmer:DDA       195 non-null    float64
#  15  NHR               195 non-null    float64
# ...

# %%
#As name is not having any importance so we are dropping that
data.drop('name',axis=1,inplace=True)

# %%
corr=data.corr()
corr
# Out:
#                   MDVP:Fo(Hz)  MDVP:Fhi(Hz)  ...        D2       PPE
# MDVP:Fo(Hz)          1.000000      0.400985  ...  0.177980 -0.372356
# MDVP:Fhi(Hz)         0.400985      1.000000  ...  0.176323 -0.069543
# MDVP:Flo(Hz)         0.596546      0.084951  ... -0.100629 -0.340071
# MDVP:Jitter(%)      -0.118003      0.102086  ...  0.433434  0.721543
# MDVP:Jitter(Abs)    -0.382027     -0.029198  ...  0.310694  0.748162
# MDVP:RAP            -0.076194      0.097177  ...  0.426605  0.670999
# MDVP:PPQ            -0.112165      0.091126  ...  0.412524  0.769647
# Jitter:DDP          -0.076213      0.097150  ...  0.426556  0.671005
# MDVP:Shimmer        -0.098374      0.002281  ...  0.507088  0.693771
# MDVP:Shimmer(dB)    -0.073742      0.043465  ...  0.512233  0.695058
# Shimmer:APQ3        -0.094717     -0.003743  ...  0.467265  0.645377
# Shimmer:APQ5        -0.070682     -0.009997  ...  0.502174  0.702456
# MDVP:APQ            -0.077774      0.004937  ...  0.536869  0.721694
# ...

# %%
data.isnull().sum()
# Out:
# MDVP:Fo(Hz)         0
# MDVP:Fhi(Hz)        0
# MDVP:Flo(Hz)        0
# MDVP:Jitter(%)      0
# MDVP:Jitter(Abs)    0
# MDVP:RAP            0
# MDVP:PPQ            0
# Jitter:DDP          0
# MDVP:Shimmer        0
# MDVP:Shimmer(dB)    0
# Shimmer:APQ3        0
# Shimmer:APQ5        0
# MDVP:APQ            0
# Shimmer:DDA         0
# NHR                 0
# HNR                 0
# status              0
# RPDE                0
# DFA                 0
# spread1             0
# spread2             0
# D2                  0
# PPE                 0
# dtype: int64

# %%
data.head()
# Out:
#    MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  ...   spread2        D2       PPE
# 0      119.992       157.302        74.997  ...  0.266482  2.301442  0.284654
# 1      122.400       148.650       113.819  ...  0.335590  2.486855  0.368674
# 2      116.682       131.111       111.555  ...  0.311173  2.342259  0.332634
# 3      116.676       137.871       111.366  ...  0.334147  2.405554  0.368975
# 4      116.014       141.781       110.655  ...  0.234513  2.332180  0.410335
#
# [5 rows x 23 columns]

# %%
data.describe()
# Out:
#        MDVP:Fo(Hz)  MDVP:Fhi(Hz)  ...          D2         PPE
# count   195.000000    195.000000  ...  195.000000  195.000000
# mean    154.228641    197.104918  ...    2.381826    0.206552
# std      41.390065     91.491548  ...    0.382799    0.090119
# min      88.333000    102.145000  ...    1.423287    0.044539
# 25%     117.572000    134.862500  ...    2.099125    0.137451
# 50%     148.790000    175.829000  ...    2.361532    0.194052
# 75%     182.769000    224.205500  ...    2.636456    0.252980
# max     260.105000    592.030000  ...    3.671155    0.527367
#
# [8 rows x 23 columns]

# %%
data.hist(bins=20,figsize=(20,20))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f1449e70f90>,
# ...
#       dtype=object)

# %%
plt.figure(figsize=(20,20))
sns.heatmap(corr,cbar=False,
square=True, fmt='.2%',annot=True,cmap='Blues')
plt.title('Histogram')
# Out:
# Text(0.5, 1.0, 'Histogram')
